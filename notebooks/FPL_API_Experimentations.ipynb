# %%
1+1
# Out:
# 2

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from agents import Agent, Runner, function_tool
from dotenv import load_dotenv
import os
import yt_dlp
from typing import Any
import requests

# %% [markdown]
# # Experimenting with FPL API

# %%
from __future__ import annotations

import requests
from typing import Any


class FPLService:
    BASE_URL = "https://fantasy.premierleague.com/api"

    def __init__(self, timeout: int = 20) -> None:
        self.timeout = timeout
        self.session = requests.Session()
        self.session.headers.update(
            {
                "User-Agent": "fpl-agent/0.1",
                "Accept": "application/json",
            }
        )

    def _get(self, path: str) -> Any:
        url = f"{self.BASE_URL}{path}"
        response = self.session.get(url, timeout=self.timeout)
        response.raise_for_status()
        return response.json()

    def get_bootstrap_static(self) -> dict[str, Any]:
        return self._get("/bootstrap-static/")

    def get_fixtures(self) -> list[dict[str, Any]]:
        return self._get("/fixtures/")

    def get_event_live(self, gameweek: int) -> dict[str, Any]:
        return self._get(f"/event/{gameweek}/live/")

    def get_element_summary(self, player_id: int) -> dict[str, Any]:
        return self._get(f"/element-summary/{player_id}/")

    def get_entry(self, team_id: int) -> dict[str, Any]:
        return self._get(f"/entry/{team_id}/")

    def get_entry_picks(self, team_id: int, gameweek: int) -> dict[str, Any]:
        return self._get(f"/entry/{team_id}/event/{gameweek}/picks/")

    def get_my_team(self, team_id: int, gameweek: int) -> dict[str, Any]:
        return self._get(f"/entry/{team_id}/event/{gameweek}/picks/")

    def get_player_news(self) -> list[dict[str, Any]]:
        data = self.get_bootstrap_static()
        players = data.get("elements", [])
        teams = {team["id"]: team["name"] for team in data.get("teams", [])}

        news_items: list[dict[str, Any]] = []

        for player in players:
            news_text = (player.get("news") or "").strip()
            if not news_text:
                continue

            news_items.append(
                {
                    "player_id": player["id"],
                    "name": player["web_name"],
                    "team_id": player["team"],
                    "team_name": teams.get(player["team"]),
                    "status": player.get("status"),
                    "chance_of_playing_next_round": player.get("chance_of_playing_next_round"),
                    "chance_of_playing_this_round": player.get("chance_of_playing_this_round"),
                    "news": news_text,
                }
            )

        return news_items

# %%
import pandas as pd

fpl = FPLService()
bootstrap = fpl.get_bootstrap_static()

players_df = pd.DataFrame(bootstrap["elements"])[
    [
        "id",
        "first_name",
        "second_name",
        "web_name",
        "team",
        "element_type",
        "now_cost",
        "total_points",
        "minutes",
        "goals_scored",
        "assists",
        "selected_by_percent",
    ]
]

teams_df = pd.DataFrame(bootstrap["teams"])[
    [
        "id",
        "name",
        "short_name",
        "strength",
        "strength_attack_home",
        "strength_attack_away",
        "strength_defence_home",
        "strength_defence_away",
    ]
]

gameweeks_df = pd.DataFrame(bootstrap["events"])[
    [
        "id",
        "name",
        "deadline_time",
        "finished",
        "is_current",
        "is_next",
    ]
]

# %%
players_df.head(50)
# Out:
#      id first_name            second_name         web_name  team  \
# 0     1      David            Raya Martín             Raya     1
# 1     2       Kepa  Arrizabalaga Revuelta     Arrizabalaga     1
# 2     3       Karl                   Hein             Hein     1
# 3     4      Tommy                Setford          Setford     1
# 4     5    Gabriel   dos Santos Magalhães          Gabriel     1
# 5     6    William                 Saliba           Saliba     1
# 6     7   Riccardo              Calafiori        Calafiori     1
# 7     8    Jurriën                 Timber         J.Timber     1
# 8     9      Jakub                 Kiwior           Kiwior     1
# 9    10      Myles           Lewis-Skelly     Lewis-Skelly     1
# 10   11   Benjamin                  White            White     1
# 11   13    Brayden                 Clarke           Clarke     1
# 12   14    Maldini                Kacurri          Kacurri     1
# 13   15       Josh                Nichols          Nichols     1
# 14   16     Bukayo                   Saka             Saka     1
# 15   17     Martin               Ødegaard         Ødegaard     1
# 16   18       Noni                Madueke          Madueke     1
# 17   19    Gabriel       Martinelli Silva       Martinelli     1
# 18   20    Leandro               Trossard         Trossard     1
# 19   21     Declan                   Rice             Rice     1
# 20   22      Mikel           Merino Zazón           Merino     1
# 21   23      Fábio        Ferreira Vieira     Fábio Vieira     1
# 22   24  Christian               Nørgaard         Nørgaard     1
# 23   25      Ethan                Nwaneri          Nwaneri     1
# 24   26     Martín       Zubimendi Ibáñez        Zubimendi     1
# 25   28     Ismeal                  Kabia            Kabia     1
# 26   29     Albert          Sambi Lokonga            Sambi     1
# 27   30        Kai                Havertz          Havertz     1
# 28   31    Gabriel      Fernando de Jesus          G.Jesus     1
# 29  266   Eberechi                    Eze              Eze     1
# 30  662  Cristhian               Mosquera         Mosquera     1
# 31  666     Viktor               Gyökeres         Gyökeres     1
# 32  700        Max                 Dowman           Dowman     1
# 33  711      Andre        Harriman-Annous  Harriman-Annous     1
# 34  725      Piero               Hincapié         Hincapie     1
# 35  759      Marli                 Salmon           Salmon     1
# 36   32   Emiliano        Martínez Romero         Martinez     2
# 37   33      Marco                  Bizot          M.Bizot     2
# 38   34        Joe                  Gauci            Gauci     2
# 39   35      Filip              Marschall        Marschall     2
# 40   36      Matty                   Cash             Cash     2
# 41   37      Lucas                  Digne            Digne     2
# 42   38       Ezri            Konsa Ngoyo            Konsa     2
# 43   39        Ian                Maatsen          Maatsen     2
# 44   40     Tyrone                  Mings            Mings     2
# 45   41        Pau                 Torres              Pau     2
# 46   42     Andrés                 García         A.García     2
# 47   43       Álex          Moreno Lopera      Alex Moreno     2
# 48   44     Lamare                Bogarde          Bogarde     2
# 49   45       Lino          da Cruz Sousa            Sousa     2
#
#     element_type  now_cost  total_points  minutes  goals_scored  assists  \
# 0              1        60           129     2790             0        0
# 1              1        40             0        0             0        0
# 2              1        40             0        0             0        0
# 3              1        39             0        0             0        0
# 4              2        72           173     2165             3        4
# 5              2        61           107     2074             1        0
# 6              2        56            93     1446             1        2
# 7              2        63           149     2452             3        6
# 8              2        54             0        0             0        0
# 9              2        50            12      311             0        0
# 10             2        51            30      409             0        1
# 11             2        37             0        0             0        0
# 12             2        39             0        0             0        0
# 13             2        37             0        0             0        0
# 14             3        98           133     1995             6        8
# 15             3        78            62     1070             1        6
# 16             3        68            54      889             2        1
# 17             3        68            47      839             1        4
# 18             3        66            99     1675             5        5
# 19             3        73           163     2580             4        9
# 20             3        54            66      996             4        3
# 21             3        54             0        0             0        0
# 22             3        51             6       56             0        0
# 23             3        50             8      165             0        0
# 24             3        51           117     2597             5        1
# 25             3        45             0        0             0        0
# 26             3        45             0        0             0        0
# 27             4        73            12      261             0        1
# 28             4        64            17      304             2        0
# 29             3        72            94     1494             6        3
# 30             2        53            28      667             0        0
# 31             4        88           101     1888            11        0
# 32             3        42            11       43             1        1
# 33             3        44             0        0             0        0
# 34             2        51            74     1499             1        2
# 35             2        40             0        0             0        0
# 36             1        51           105     2385             0        0
# 37             1        42            11      405             0        0
# 38             1        40             0        0             0        0
# 39             1        40             0        0             0        0
# 40             2        47           106     2442             3        2
# 41             2        45            85     1549             0        5
# 42             2        44            95     2675             0        1
# 43             2        42            40     1251             0        0
# 44             2        43            44      962             0        1
# 45             2        43            56     1386             0        1
# 46             2        39             3       37             0        0
# 47             2        40             0        0             0        0
# 48             2        40            34      797             0        0
# 49             2        38             0        0             0        0
#
#    selected_by_percent
# 0                 34.6
# 1                  0.4
# 2                  0.2
# 3                  0.2
# 4                 43.0
# 5                 13.2
# 6                  6.0
# 7                 26.8
# 8                  0.0
# 9                  1.4
# 10                 0.5
# 11                 0.4
# 12                 0.1
# 13                 0.2
# 14                 8.0
# 15                 1.5
# 16                 0.9
# 17                 0.9
# 18                 0.8
# 19                26.2
# 20                 0.8
# 21                 0.0
# 22                 0.1
# 23                 0.1
# 24                 3.6
# 25                 0.1
# 26                 0.0
# 27                 0.5
# 28                 0.3
# 29                 7.9
# 30                 0.1
# 31                11.6
# 32                 0.6
# 33                 0.0
# 34                 0.9
# 35                 0.0
# 36                 4.8
# 37                 0.4
# 38                 0.1
# 39                 0.0
# 40                 8.6
# 41                 1.6
# 42                 8.2
# 43                 0.6
# 44                 0.7
# 45                 0.3
# 46                 0.2
# 47                 1.6
# 48                 0.5
# 49                 0.3

# %% [markdown]
# ## Creating agent tools

# %%
# src/tools/fpl_api.py
from __future__ import annotations

from typing import Any
from pydantic import BaseModel

from src.services.fpl_service import FPLService

fpl_service = FPLService()


class BootstrapResponse(BaseModel):
    """Structured summary of the main FPL bootstrap dataset."""

    total_players: int
    total_teams: int
    total_events: int
    sample_players: list[dict[str, Any]]


def get_bootstrap_data() -> dict[str, Any]:
    """Return a compact summary of the FPL bootstrap-static dataset.

    Includes overall counts for players, teams, and events, plus a small
    sample of player records for quick inspection.
    """
    data = fpl_service.get_bootstrap_static()
    return BootstrapResponse(
        total_players=len(data.get("elements", [])),
        total_teams=len(data.get("teams", [])),
        total_events=len(data.get("events", [])),
        sample_players=[
            {
                "id": p["id"],
                "web_name": p["web_name"],
                "team": p["team"],
                "now_cost": p["now_cost"],
                "total_points": p["total_points"],
                "form": p["form"],
                "minutes": p["minutes"],
                "selected_by_percent": p["selected_by_percent"],
            }
            for p in data.get("elements", [])[:10]
        ],
    ).model_dump()


def get_fixtures() -> list[dict[str, Any]]:
    """Return a trimmed list of upcoming or recent FPL fixtures."""
    fixtures = fpl_service.get_fixtures()
    return fixtures[:20]


def get_player_news() -> list[dict[str, Any]]:
    """Return player availability and injury news from FPL bootstrap data."""
    return fpl_service.get_player_news()


def get_live_gameweek_data(gameweek: int) -> dict[str, Any]:
    """Return live FPL data for a specific gameweek.

    Args:
        gameweek: The FPL gameweek number to fetch.
    """
    return fpl_service.get_event_live(gameweek)


def get_player_detail(player_id: int) -> dict[str, Any]:
    """Return detailed FPL history and fixture data for one player.

    Args:
        player_id: The FPL player ID.
    """
    return fpl_service.get_element_summary(player_id)


from __future__ import annotations

from typing import Any


def get_manager_team(team_id: int, gameweek: int) -> dict[str, Any]:
    """Return a manager's entry details and picks for a given gameweek."""
    entry = fpl_service.get_entry(team_id)
    picks = fpl_service.get_entry_picks(team_id, gameweek)
    return {
        "entry": entry,
        "picks": picks,
    }


def get_manager_team_summary(team_id: int, gameweek: int) -> dict[str, Any]:
    """
    Return starters, bench, and automatic substitutions for a manager.

    Also attaches player names and gameweek points.
    """
    team_data = get_manager_team(team_id, gameweek)
    bootstrap = fpl_service.get_bootstrap_static()
    live = fpl_service.get_event_live(gameweek)

    picks_data = team_data["picks"]

    # player id -> player full name
    player_names: dict[int, str] = {
        player["id"]: f"{player['first_name']} {player['second_name']}"
        for player in bootstrap["elements"]
    }

    # player id -> total points in that gameweek
    player_points: dict[int, int] = {
        item["id"]: item["stats"]["total_points"]
        for item in live["elements"]
    }

    starters = []
    bench = []

    for pick in picks_data["picks"]:
        player_id = pick["element"]
        player_info = {
            "element": player_id,
            "name": player_names.get(player_id, f"Player {player_id}"),
            "position": pick["position"],
            "points": player_points.get(player_id, 0),
            "multiplier": pick["multiplier"],
            "is_captain": pick["is_captain"],
            "is_vice_captain": pick["is_vice_captain"],
        }

        if pick["position"] <= 11:
            starters.append(player_info)
        else:
            bench.append(player_info)

    automatic_substitutions = []
    for sub in picks_data.get("automatic_subs", []):
        out_id = sub["element_out"]
        in_id = sub["element_in"]

        automatic_substitutions.append(
            {
                "out_element": out_id,
                "out_name": player_names.get(out_id, f"Player {out_id}"),
                "out_points": player_points.get(out_id, 0),
                "in_element": in_id,
                "in_name": player_names.get(in_id, f"Player {in_id}"),
                "in_points": player_points.get(in_id, 0),
            }
        )

    return {
        "entry": team_data["entry"],
        "gameweek": gameweek,
        "starters": starters,
        "bench": bench,
        "automatic_substitutions": automatic_substitutions,
    }

# %%
get_manager_team(5196911, 30)["picks"]
# Out:
# {'active_chip': None,
#  'automatic_subs': [],
#  'entry_history': {'event': 30,
#   'points': 56,
#   'total_points': 1637,
#   'rank': 1627681,
#   'rank_sort': 1691629,
#   'overall_rank': 2205318,
#   'percentile_rank': 15,
#   'bank': 21,
#   'value': 1021,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'points_on_bench': 8},
#  'picks': [{'element': 470,
#    'position': 1,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 1},
#   {'element': 8,
#    'position': 2,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 2},
#   {'element': 260,
#    'position': 3,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 2},
#   {'element': 373,
#    'position': 4,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 2},
#   {'element': 74,
#    'position': 5,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 2},
#   {'element': 21,
#    'position': 6,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 3},
#   {'element': 449,
#    'position': 7,
#    'multiplier': 2,
#    'is_captain': True,
#    'is_vice_captain': False,
#    'element_type': 3},
#   {'element': 82,
#    'position': 8,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 3},
#   {'element': 249,
#    'position': 9,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 4},
#   {'element': 136,
#    'position': 10,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': True,
#    'element_type': 4},
#   {'element': 661,
#    'position': 11,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 4},
#   {'element': 220,
#    'position': 12,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 1},
#   {'element': 329,
#    'position': 13,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 3},
#   {'element': 47,
#    'position': 14,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 3},
#   {'element': 374,
#    'position': 15,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False,
#    'element_type': 2}]}

# %%
summary = get_manager_team_summary(team_id=5196911, gameweek=30)

print("STARTERS")
for player in summary["starters"]:
    print(f"{player['name']} - {player['points']} pts")

print("\nBENCH")
for player in summary["bench"]:
    print(f"{player['name']} - {player['points']} pts")

print("\nAUTO SUBS")
for sub in summary["automatic_substitutions"]:
    print(f"{sub['out_name']} -> {sub['in_name']}")
# Out:
# STARTERS
# Martin Dúbravka - 6 pts
# Jurriën Timber - 1 pts
# Marc Guéhi - 2 pts
# Virgil van Dijk - 2 pts
# Adrien Truffert - 11 pts
# Declan Rice - 3 pts
# Bruno Borges Fernandes - 10 pts
# Antoine Semenyo - 2 pts
# João Pedro Junqueira de Jesus - 2 pts
# Igor Thiago Nascimento Rodrigues - 6 pts
# Hugo Ekitiké - 1 pts
#
# BENCH
# Robert Lynch Sánchez - 3 pts
# Harry Wilson - 3 pts
# Morgan Rogers - 2 pts
# Ibrahima Konaté - 0 pts
#
# AUTO SUBS

# %%
get_player_detail(470)
# Out:
# {'fixtures': [{'id': 313,
#    'code': 2562207,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 6,
#    'team_a_score': None,
#    'event': 32,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-04-11T14:00:00Z',
#    'event_name': 'Gameweek 32',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 329,
#    'code': 2562223,
#    'team_h': 16,
#    'team_h_score': None,
#    'team_a': 3,
#    'team_a_score': None,
#    'event': 33,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-04-19T13:00:00Z',
#    'event_name': 'Gameweek 33',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 334,
#    'code': 2562228,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 34,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-04-26T13:00:00Z',
#    'event_name': 'Gameweek 34',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 347,
#    'code': 2562241,
#    'team_h': 11,
#    'team_h_score': None,
#    'team_a': 3,
#    'team_a_score': None,
#    'event': 35,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-05-01T19:00:00Z',
#    'event_name': 'Gameweek 35',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 352,
#    'code': 2562246,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 2,
#    'team_a_score': None,
#    'event': 36,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-05-09T14:00:00Z',
#    'event_name': 'Gameweek 36',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 361,
#    'code': 2562256,
#    'team_h': 1,
#    'team_h_score': None,
#    'team_a': 3,
#    'team_a_score': None,
#    'event': 37,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-05-17T14:00:00Z',
#    'event_name': 'Gameweek 37',
#    'is_home': False,
#    'difficulty': 5},
#   {'id': 372,
#    'code': 2562266,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 20,
#    'team_a_score': None,
#    'event': 38,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2026-05-24T15:00:00Z',
#    'event_name': 'Gameweek 38',
#    'is_home': True,
#    'difficulty': 2}],
#  'history': [{'element': 470,
#    'fixture': 6,
#    'opponent_team': 18,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-08-16T14:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 0,
#    'round': 1,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 5,
#    'influence': '25.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.6',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 6,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.32',
#    'value': 40,
#    'transfers_balance': 0,
#    'selected': 3377673,
#    'transfers_in': 0,
#    'transfers_out': 0},
#   {'element': 470,
#    'fixture': 14,
#    'opponent_team': 17,
#    'total_points': 6,
#    'was_home': True,
#    'kickoff_time': '2025-08-23T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 2,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 1,
#    'bonus': 0,
#    'bps': 25,
#    'influence': '10.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.1',
#    'clearances_blocks_interceptions': 2,
#    'recoveries': 11,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.77',
#    'value': 40,
#    'transfers_balance': 103907,
#    'selected': 3747160,
#    'transfers_in': 147768,
#    'transfers_out': 43861},
#   {'element': 470,
#    'fixture': 26,
#    'opponent_team': 14,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-08-30T14:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 2,
#    'round': 3,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 5,
#    'bonus': 0,
#    'bps': 8,
#    'influence': '35.4',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '3.5',
#    'clearances_blocks_interceptions': 2,
#    'recoveries': 7,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '3.63',
#    'value': 40,
#    'transfers_balance': 60622,
#    'selected': 3866489,
#    'transfers_in': 146062,
#    'transfers_out': 85440},
#   {'element': 470,
#    'fixture': 34,
#    'opponent_team': 12,
#    'total_points': 3,
#    'was_home': True,
#    'kickoff_time': '2025-09-14T13:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 1,
#    'round': 4,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 15,
#    'influence': '21.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.1',
#    'clearances_blocks_interceptions': 4,
#    'recoveries': 11,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.45',
#    'value': 40,
#    'transfers_balance': 53364,
#    'selected': 3978017,
#    'transfers_in': 170483,
#    'transfers_out': 117119},
#   {'element': 470,
#    'fixture': 44,
#    'opponent_team': 16,
#    'total_points': 4,
#    'was_home': True,
#    'kickoff_time': '2025-09-20T14:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 1,
#    'round': 5,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 7,
#    'bonus': 0,
#    'bps': 24,
#    'influence': '49.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '5.0',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 11,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.10',
#    'value': 40,
#    'transfers_balance': 59338,
#    'selected': 4064577,
#    'transfers_in': 107525,
#    'transfers_out': 48187},
#   {'element': 470,
#    'fixture': 57,
#    'opponent_team': 13,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2025-09-27T14:00:00Z',
#    'team_h_score': 5,
#    'team_a_score': 1,
#    'round': 6,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 5,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 5,
#    'bonus': 0,
#    'bps': 4,
#    'influence': '40.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '4.1',
#    'clearances_blocks_interceptions': 2,
#    'recoveries': 5,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.03',
#    'value': 40,
#    'transfers_balance': 59028,
#    'selected': 4130889,
#    'transfers_in': 146605,
#    'transfers_out': 87577},
#   {'element': 470,
#    'fixture': 62,
#    'opponent_team': 2,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-10-05T13:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 1,
#    'round': 7,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 5,
#    'bonus': 0,
#    'bps': 12,
#    'influence': '34.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '3.5',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 4,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.37',
#    'value': 40,
#    'transfers_balance': -4465,
#    'selected': 4138990,
#    'transfers_in': 71787,
#    'transfers_out': 76252},
#   {'element': 470,
#    'fixture': 72,
#    'opponent_team': 11,
#    'total_points': 9,
#    'was_home': True,
#    'kickoff_time': '2025-10-18T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 8,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 4,
#    'bonus': 2,
#    'bps': 32,
#    'influence': '32.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '3.3',
#    'clearances_blocks_interceptions': 3,
#    'recoveries': 7,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.63',
#    'value': 40,
#    'transfers_balance': 25111,
#    'selected': 4185019,
#    'transfers_in': 85544,
#    'transfers_out': 60433},
#   {'element': 470,
#    'fixture': 90,
#    'opponent_team': 20,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-10-26T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 3,
#    'round': 9,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 5,
#    'bonus': 0,
#    'bps': 16,
#    'influence': '40.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '4.0',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 12,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.52',
#    'value': 40,
#    'transfers_balance': 44731,
#    'selected': 4241246,
#    'transfers_in': 71187,
#    'transfers_out': 26456},
#   {'element': 470,
#    'fixture': 92,
#    'opponent_team': 1,
#    'total_points': 2,
#    'was_home': True,
#    'kickoff_time': '2025-11-01T15:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 2,
#    'round': 10,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 5,
#    'bonus': 0,
#    'bps': 14,
#    'influence': '35.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '3.6',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 6,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.42',
#    'value': 40,
#    'transfers_balance': 5316,
#    'selected': 4239599,
#    'transfers_in': 52472,
#    'transfers_out': 47156},
#   {'element': 470,
#    'fixture': 110,
#    'opponent_team': 19,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-11-08T15:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 2,
#    'round': 11,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 2,
#    'influence': '18.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.8',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 5,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '3.02',
#    'value': 40,
#    'transfers_balance': 17671,
#    'selected': 4274100,
#    'transfers_in': 44651,
#    'transfers_out': 26980},
#   {'element': 470,
#    'fixture': 114,
#    'opponent_team': 7,
#    'total_points': 2,
#    'was_home': True,
#    'kickoff_time': '2025-11-22T12:30:00Z',
#    'team_h_score': 0,
#    'team_a_score': 2,
#    'round': 12,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 12,
#    'influence': '25.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.5',
#    'clearances_blocks_interceptions': 5,
#    'recoveries': 12,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.01',
#    'expected_goals_conceded': '1.72',
#    'value': 40,
#    'transfers_balance': -13978,
#    'selected': 4246866,
#    'transfers_in': 35863,
#    'transfers_out': 49841},
#   {'element': 470,
#    'fixture': 122,
#    'opponent_team': 5,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2025-11-29T15:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 1,
#    'round': 13,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 1,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '7.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.7',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 13,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.01',
#    'expected_goals_conceded': '3.06',
#    'value': 40,
#    'transfers_balance': -18128,
#    'selected': 4177393,
#    'transfers_in': 20357,
#    'transfers_out': 38485},
#   {'element': 470,
#    'fixture': 134,
#    'opponent_team': 8,
#    'total_points': 2,
#    'was_home': True,
#    'kickoff_time': '2025-12-03T19:30:00Z',
#    'team_h_score': 0,
#    'team_a_score': 1,
#    'round': 14,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 2,
#    'bonus': 0,
#    'bps': 14,
#    'influence': '21.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.1',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 6,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.01',
#    'expected_goals_conceded': '0.59',
#    'value': 40,
#    'transfers_balance': -5513,
#    'selected': 4246340,
#    'transfers_in': 22374,
#    'transfers_out': 27887},
#   {'element': 470,
#    'fixture': 148,
#    'opponent_team': 15,
#    'total_points': 3,
#    'was_home': False,
#    'kickoff_time': '2025-12-06T15:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 1,
#    'round': 15,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 6,
#    'bonus': 0,
#    'bps': 13,
#    'influence': '32.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '3.3',
#    'clearances_blocks_interceptions': 4,
#    'recoveries': 8,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.77',
#    'value': 40,
#    'transfers_balance': -13058,
#    'selected': 4226333,
#    'transfers_in': 27370,
#    'transfers_out': 40428},
#   {'element': 470,
#    'fixture': 153,
#    'opponent_team': 10,
#    'total_points': 1,
#    'was_home': True,
#    'kickoff_time': '2025-12-13T17:30:00Z',
#    'team_h_score': 2,
#    'team_a_score': 3,
#    'round': 16,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 1,
#    'bonus': 0,
#    'bps': -1,
#    'influence': '11.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.1',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 6,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.23',
#    'value': 40,
#    'transfers_balance': -9200,
#    'selected': 4224264,
#    'transfers_in': 73614,
#    'transfers_out': 82814},
#   {'element': 470,
#    'fixture': 162,
#    'opponent_team': 4,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2025-12-20T15:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 1,
#    'round': 17,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 4,
#    'influence': '4.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.5',
#    'clearances_blocks_interceptions': 2,
#    'recoveries': 5,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.41',
#    'value': 40,
#    'transfers_balance': -7041,
#    'selected': 4225682,
#    'transfers_in': 41121,
#    'transfers_out': 48162},
#   {'element': 470,
#    'fixture': 173,
#    'opponent_team': 9,
#    'total_points': 11,
#    'was_home': True,
#    'kickoff_time': '2025-12-27T15:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 0,
#    'round': 18,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 6,
#    'bonus': 3,
#    'bps': 43,
#    'influence': '55.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '5.6',
#    'clearances_blocks_interceptions': 7,
#    'recoveries': 7,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.85',
#    'value': 40,
#    'transfers_balance': 1640,
#    'selected': 4207021,
#    'transfers_in': 40891,
#    'transfers_out': 39251},
#   {'element': 470,
#    'fixture': 183,
#    'opponent_team': 15,
#    'total_points': 2,
#    'was_home': True,
#    'kickoff_time': '2025-12-30T19:30:00Z',
#    'team_h_score': 1,
#    'team_a_score': 3,
#    'round': 19,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 4,
#    'bonus': 0,
#    'bps': 5,
#    'influence': '28.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.8',
#    'clearances_blocks_interceptions': 3,
#    'recoveries': 7,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.31',
#    'value': 40,
#    'transfers_balance': 13446,
#    'selected': 4209467,
#    'transfers_in': 41768,
#    'transfers_out': 28322},
#   {'element': 470,
#    'fixture': 193,
#    'opponent_team': 6,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2026-01-03T15:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 20,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 2,
#    'bonus': 0,
#    'bps': 10,
#    'influence': '19.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.9',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 8,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.45',
#    'value': 40,
#    'transfers_balance': -1001,
#    'selected': 4267769,
#    'transfers_in': 45045,
#    'transfers_out': 46046},
#   {'element': 470,
#    'fixture': 204,
#    'opponent_team': 14,
#    'total_points': 3,
#    'was_home': True,
#    'kickoff_time': '2026-01-07T20:15:00Z',
#    'team_h_score': 2,
#    'team_a_score': 2,
#    'round': 21,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 6,
#    'bonus': 0,
#    'bps': 19,
#    'influence': '51.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '5.1',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 11,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.55',
#    'value': 40,
#    'transfers_balance': -23194,
#    'selected': 4246236,
#    'transfers_in': 35207,
#    'transfers_out': 58401},
#   {'element': 470,
#    'fixture': 215,
#    'opponent_team': 12,
#    'total_points': 5,
#    'was_home': False,
#    'kickoff_time': '2026-01-17T15:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 1,
#    'round': 22,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 8,
#    'bonus': 1,
#    'bps': 25,
#    'influence': '46.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '4.7',
#    'clearances_blocks_interceptions': 3,
#    'recoveries': 11,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '3.18',
#    'value': 40,
#    'transfers_balance': -32219,
#    'selected': 4218771,
#    'transfers_in': 39390,
#    'transfers_out': 71609},
#   {'element': 470,
#    'fixture': 224,
#    'opponent_team': 18,
#    'total_points': 5,
#    'was_home': True,
#    'kickoff_time': '2026-01-24T15:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 2,
#    'round': 23,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 9,
#    'bonus': 1,
#    'bps': 26,
#    'influence': '62.4',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '6.2',
#    'clearances_blocks_interceptions': 2,
#    'recoveries': 8,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.05',
#    'value': 40,
#    'transfers_balance': -2920,
#    'selected': 4221543,
#    'transfers_in': 31506,
#    'transfers_out': 34426},
#   {'element': 470,
#    'fixture': 238,
#    'opponent_team': 17,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2026-02-02T20:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 0,
#    'round': 24,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 1,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 6,
#    'influence': '24.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.5',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 6,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.47',
#    'value': 40,
#    'transfers_balance': 10685,
#    'selected': 4234686,
#    'transfers_in': 65443,
#    'transfers_out': 54758},
#   {'element': 470,
#    'fixture': 244,
#    'opponent_team': 19,
#    'total_points': 1,
#    'was_home': True,
#    'kickoff_time': '2026-02-07T15:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 2,
#    'round': 25,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 2,
#    'bonus': 0,
#    'bps': 9,
#    'influence': '16.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.7',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 10,
#    'tackles': 1,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.02',
#    'value': 40,
#    'transfers_balance': 3651,
#    'selected': 4239808,
#    'transfers_in': 39797,
#    'transfers_out': 36146},
#   {'element': 470,
#    'fixture': 254,
#    'opponent_team': 8,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2026-02-11T19:40:00Z',
#    'team_h_score': 2,
#    'team_a_score': 3,
#    'round': 26,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 1,
#    'bonus': 0,
#    'bps': 4,
#    'influence': '11.4',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.1',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 9,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.80',
#    'value': 40,
#    'transfers_balance': -14802,
#    'selected': 4215425,
#    'transfers_in': 31500,
#    'transfers_out': 46302},
#   {'element': 470,
#    'fixture': 263,
#    'opponent_team': 7,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2026-02-21T15:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 1,
#    'round': 27,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 1,
#    'bonus': 0,
#    'bps': 4,
#    'influence': '7.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.7',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 2,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.99',
#    'value': 40,
#    'transfers_balance': -15568,
#    'selected': 4215728,
#    'transfers_in': 25881,
#    'transfers_out': 41449},
#   {'element': 470,
#    'fixture': 274,
#    'opponent_team': 5,
#    'total_points': 0,
#    'was_home': True,
#    'kickoff_time': '2026-02-28T15:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 4,
#    'round': 28,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 4,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 2,
#    'bonus': 0,
#    'bps': -2,
#    'influence': '15.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.6',
#    'clearances_blocks_interceptions': 3,
#    'recoveries': 8,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.01',
#    'expected_goals_conceded': '2.25',
#    'value': 40,
#    'transfers_balance': -13362,
#    'selected': 4204321,
#    'transfers_in': 19788,
#    'transfers_out': 33150},
#   {'element': 470,
#    'fixture': 284,
#    'opponent_team': 9,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2026-03-03T19:30:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 29,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 9,
#    'influence': '23.4',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.3',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 8,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '1.30',
#    'value': 40,
#    'transfers_balance': -20718,
#    'selected': 4183126,
#    'transfers_in': 14906,
#    'transfers_out': 35624},
#   {'element': 470,
#    'fixture': 293,
#    'opponent_team': 4,
#    'total_points': 6,
#    'was_home': True,
#    'kickoff_time': '2026-03-14T15:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 0,
#    'round': 30,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 2,
#    'bonus': 0,
#    'bps': 26,
#    'influence': '17.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '1.7',
#    'clearances_blocks_interceptions': 1,
#    'recoveries': 9,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '2.55',
#    'value': 40,
#    'transfers_balance': -12411,
#    'selected': 4176284,
#    'transfers_in': 21693,
#    'transfers_out': 34104},
#   {'element': 470,
#    'fixture': 305,
#    'opponent_team': 10,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2026-03-21T15:00:00Z',
#    'team_h_score': 3,
#    'team_a_score': 1,
#    'round': 31,
#    'modified': False,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 3,
#    'bonus': 0,
#    'bps': 5,
#    'influence': '20.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '2.1',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 9,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '3.15',
#    'value': 40,
#    'transfers_balance': -16272,
#    'selected': 4026574,
#    'transfers_in': 14812,
#    'transfers_out': 31084}],
#  'history_past': [{'season_name': '2017/18',
#    'element_code': 67089,
#    'start_cost': 45,
#    'end_cost': 45,
#    'total_points': 53,
#    'minutes': 1080,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 4,
#    'goals_conceded': 11,
#    'own_goals': 0,
#    'penalties_saved': 1,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 26,
#    'bonus': 5,
#    'bps': 215,
#    'influence': '234.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '23.3',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2018/19',
#    'element_code': 67089,
#    'start_cost': 50,
#    'end_cost': 50,
#    'total_points': 131,
#    'minutes': 3420,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 11,
#    'goals_conceded': 48,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 1,
#    'red_cards': 0,
#    'saves': 96,
#    'bonus': 10,
#    'bps': 647,
#    'influence': '783.6',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '78.4',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2019/20',
#    'element_code': 67089,
#    'start_cost': 50,
#    'end_cost': 51,
#    'total_points': 143,
#    'minutes': 3420,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 11,
#    'goals_conceded': 58,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 139,
#    'bonus': 7,
#    'bps': 719,
#    'influence': '1019.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '102.0',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2020/21',
#    'element_code': 67089,
#    'start_cost': 50,
#    'end_cost': 48,
#    'total_points': 48,
#    'minutes': 1170,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 3,
#    'goals_conceded': 19,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 45,
#    'bonus': 6,
#    'bps': 255,
#    'influence': '346.8',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '34.6',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2021/22',
#    'element_code': 67089,
#    'start_cost': 45,
#    'end_cost': 44,
#    'total_points': 96,
#    'minutes': 2340,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 8,
#    'goals_conceded': 35,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 1,
#    'red_cards': 0,
#    'saves': 73,
#    'bonus': 9,
#    'bps': 465,
#    'influence': '590.8',
#    'creativity': '20.0',
#    'threat': '0.0',
#    'ict_index': '61.1',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2022/23',
#    'element_code': 67089,
#    'start_cost': 45,
#    'end_cost': 41,
#    'total_points': 11,
#    'minutes': 156,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 10,
#    'bonus': 1,
#    'bps': 49,
#    'influence': '54.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '5.4',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '3.33'},
#   {'season_name': '2023/24',
#    'element_code': 67089,
#    'start_cost': 40,
#    'end_cost': 43,
#    'total_points': 75,
#    'minutes': 1984,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 4,
#    'goals_conceded': 42,
#    'own_goals': 0,
#    'penalties_saved': 1,
#    'penalties_missed': 0,
#    'yellow_cards': 1,
#    'red_cards': 0,
#    'saves': 88,
#    'bonus': 3,
#    'bps': 426,
#    'influence': '661.0',
#    'creativity': '10.0',
#    'threat': '0.0',
#    'ict_index': '67.2',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 22,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '44.34'},
#   {'season_name': '2024/25',
#    'element_code': 67089,
#    'start_cost': 45,
#    'end_cost': 40,
#    'total_points': 44,
#    'minutes': 900,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 5,
#    'goals_conceded': 12,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 29,
#    'bonus': 2,
#    'bps': 160,
#    'influence': '220.2',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '22.0',
#    'clearances_blocks_interceptions': 0,
#    'recoveries': 0,
#    'tackles': 0,
#    'defensive_contribution': 0,
#    'starts': 10,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '11.19'}]}

# %%
get_bootstrap_data()
# Out:
# {'total_players': 825,
#  'total_teams': 20,
#  'total_events': 38,
#  'sample_players': [{'id': 1,
#    'web_name': 'Raya',
#    'team': 1,
#    'now_cost': 60,
#    'total_points': 129,
#    'form': '7.0',
#    'minutes': 2790,
#    'selected_by_percent': '34.6'},
#   {'id': 2,
#    'web_name': 'Arrizabalaga',
#    'team': 1,
#    'now_cost': 40,
#    'total_points': 0,
#    'form': '0.0',
#    'minutes': 0,
#    'selected_by_percent': '0.4'},
#   {'id': 3,
#    'web_name': 'Hein',
#    'team': 1,
#    'now_cost': 40,
#    'total_points': 0,
#    'form': '0.0',
#    'minutes': 0,
#    'selected_by_percent': '0.2'},
#   {'id': 4,
#    'web_name': 'Setford',
#    'team': 1,
#    'now_cost': 39,
#    'total_points': 0,
#    'form': '0.0',
#    'minutes': 0,
#    'selected_by_percent': '0.2'},
#   {'id': 5,
#    'web_name': 'Gabriel',
#    'team': 1,
#    'now_cost': 72,
#    'total_points': 173,
#    'form': '10.0',
#    'minutes': 2165,
#    'selected_by_percent': '43.0'},
#   {'id': 6,
#    'web_name': 'Saliba',
#    'team': 1,
#    'now_cost': 61,
#    'total_points': 107,
#    'form': '5.5',
#    'minutes': 2074,
#    'selected_by_percent': '13.2'},
#   {'id': 7,
#    'web_name': 'Calafiori',
#    'team': 1,
#    'now_cost': 56,
#    'total_points': 93,
#    'form': '3.5',
#    'minutes': 1446,
#    'selected_by_percent': '6.0'},
#   {'id': 8,
#    'web_name': 'J.Timber',
#    'team': 1,
#    'now_cost': 63,
#    'total_points': 149,
#    'form': '7.0',
#    'minutes': 2452,
#    'selected_by_percent': '26.8'},
#   {'id': 9,
#    'web_name': 'Kiwior',
#    'team': 1,
#    'now_cost': 54,
#    'total_points': 0,
#    'form': '0.0',
#    'minutes': 0,
#    'selected_by_percent': '0.0'},
#   {'id': 10,
#    'web_name': 'Lewis-Skelly',
#    'team': 1,
#    'now_cost': 50,
#    'total_points': 12,
#    'form': '0.0',
#    'minutes': 311,
#    'selected_by_percent': '1.4'}]}

# %%
get_player_news()[30:40]
# Out:
# [{'player_id': 61,
#   'name': 'Dendoncker',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'Has joined Real Oviedo permanently.'},
#  {'player_id': 62,
#   'name': 'Jimoh-Aloba',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined West Brom on loan for the rest of the season.'},
#  {'player_id': 63,
#   'name': 'Young',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined Reading on loan for the rest of the season.'},
#  {'player_id': 65,
#   'name': 'Redmond',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined Huddersfield Town on loan for the rest of the season.'},
#  {'player_id': 456,
#   'name': 'Sancho',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'd',
#   'chance_of_playing_next_round': 75,
#   'chance_of_playing_this_round': 100,
#   'news': 'Shoulder injury - 75% chance of playing'},
#  {'player_id': 701,
#   'name': 'Rowe',
#   'team_id': 2,
#   'team_name': 'Aston Villa',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined Annecy on loan for the rest of the season.'},
#  {'player_id': 184,
#   'name': 'Green',
#   'team_id': 3,
#   'team_name': 'Burnley',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined FC Fredericia permanently.'},
#  {'player_id': 186,
#   'name': 'Roberts',
#   'team_id': 3,
#   'team_name': 'Burnley',
#   'status': 'd',
#   'chance_of_playing_next_round': 25,
#   'chance_of_playing_this_round': 0,
#   'news': 'Achilles injury - 25% chance of playing'},
#  {'player_id': 188,
#   'name': 'Delcroix',
#   'team_id': 3,
#   'team_name': 'Burnley',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'has joined Lugano permanently.'},
#  {'player_id': 189,
#   'name': 'Dodgson',
#   'team_id': 3,
#   'team_name': 'Burnley',
#   'status': 'u',
#   'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'news': 'Has joined Stockport County on loan for the rest of the season.'}]

# %% [markdown]
# ## Adding FPL analysis logic

# %%
# src/tools/fpl_analysis.py
from __future__ import annotations

from typing import Any

from agents import function_tool

#from src.services.fpl_service import FPLService

fpl_service = FPLService()


def rank_captain_candidates(top_n: int = 5) -> list[dict[str, Any]]:
    data = fpl_service.get_bootstrap_static()
    players = data.get("elements", [])

    scored = []
    for p in players:
        minutes = p.get("minutes", 0)
        form = float(p.get("form", 0) or 0)
        points_per_game = float(p.get("points_per_game", 0) or 0)
        ownership = float(p.get("selected_by_percent", 0) or 0)

        if minutes < 400:
            continue

        score = (
            form * 0.45
            + points_per_game * 0.35
            + min(ownership, 50) * 0.02
        )

        scored.append(
            {
                "id": p["id"],
                "name": p["web_name"],
                "team_id": p["team"],
                "position_id": p["element_type"],
                "price": p["now_cost"] / 10,
                "form": form,
                "points_per_game": points_per_game,
                "ownership": ownership,
                "score": round(score, 2),
            }
        )

    scored.sort(key=lambda x: x["score"], reverse=True)
    return scored[:top_n]

# %%
rank_captain_candidates()
# Out:
# [{'id': 449,
#   'name': 'B.Fernandes',
#   'team_id': 14,
#   'position_id': 3,
#   'price': 10.3,
#   'form': 10.3,
#   'points_per_game': 6.8,
#   'ownership': 44.5,
#   'score': 7.91},
#  {'id': 5,
#   'name': 'Gabriel',
#   'team_id': 1,
#   'position_id': 2,
#   'price': 7.2,
#   'form': 10.0,
#   'points_per_game': 6.9,
#   'ownership': 43.0,
#   'score': 7.78},
#  {'id': 249,
#   'name': 'João Pedro',
#   'team_id': 7,
#   'position_id': 4,
#   'price': 7.8,
#   'form': 7.7,
#   'points_per_game': 5.3,
#   'ownership': 50.4,
#   'score': 6.32},
#  {'id': 267,
#   'name': 'Sarr',
#   'team_id': 8,
#   'position_id': 3,
#   'price': 6.3,
#   'form': 9.0,
#   'points_per_game': 4.7,
#   'ownership': 3.8,
#   'score': 5.77},
#  {'id': 485,
#   'name': 'Gordon',
#   'team_id': 15,
#   'position_id': 3,
#   'price': 7.4,
#   'form': 9.3,
#   'points_per_game': 3.9,
#   'ownership': 7.4,
#   'score': 5.7}]

# %% [markdown]
# ## Creating an agent to make a decision

# %%
# src/agents/fpl_advisor.py
from agents import Agent

#from src.tools.fpl_api import (
 #   get_bootstrap_data,
  #  get_fixtures,
 #   get_live_gameweek_data,
   # get_player_detail,
  #  get_manager_team,
# )
# from src.tools.fpl_analysis import rank_captain_candidates


fpl_advisor = Agent(
    name="FPL Advisor",
    instructions=(
        "You are an expert Fantasy Premier League assistant. "
        "Use the available tools to answer with practical, evidence-based FPL advice. "
        "Do not invent injuries, fixtures, or stats. "
        "When recommending transfers or captaincy, explain the reasoning clearly, "
        "including form, minutes, fixture quality, and risk."
    ),
    tools=[
        function_tool(get_bootstrap_data),
        function_tool(get_fixtures),
        function_tool(get_live_gameweek_data),
        function_tool(get_player_detail),
        function_tool(get_manager_team),
        function_tool(rank_captain_candidates),
    ],
)

# %%
result = await Runner.run(
        fpl_advisor,
        "Rank the best captain picks for this gameweek and explain the top 3."
    )
print(result.final_output)
# Out:
# Here are the best captain picks for this gameweek, ranked:
#
# 1. Bruno Fernandes (Man United, MID)
# 2. Gabriel (Arsenal, DEF)
# 3. João Pedro (Brighton, FWD)
# 4. Sarr (Wolves, MID)
# 5. Gordon (Newcastle, MID)
#
# Explanations for the top 3:
#
# 1. Bruno Fernandes
#    - Form: 10.3 (highest in the league right now).
#    - Points per game: 6.8.
#    - Reasoning: Bruno is central to all of Manchester United’s attacks—he's on penalties, created a lot of chances lately, and is a reliable performer with both assist and goal potential. His consistency and involvement in big chances make him a top captaincy pick.
#
# 2. Gabriel (Arsenal)
#    - Form: 10.0.
#    - Points per game: 6.9.
#    - Reasoning: As a defender, Gabriel offers huge goal threat from set pieces, and Arsenal’s solid defense means a clean sheet is likely. He’s also in great scoring form, making him one of the rare defenders worth captaining.
#
# 3. João Pedro (Brighton)
#    - Form: 7.7.
#    - Points per game: 5.3.
#    - Reasoning: João Pedro is Brighton’s most reliable attacking outlet with penalty duties and has a favorable fixture. His high ownership also mitigates rank risk, and his form suggests he’s likely to deliver returns.
#
# These picks are based on form, reliability, and fixture quality for this gameweek. If you want more details on any individual player or their fixture, just ask!

# %%
fpl_advisor = Agent(
    name="FPL Advisor",
    instructions=(
        "You are an expert Fantasy Premier League assistant. "
        "Use the available tools to answer with practical, evidence-based FPL advice. "
        "Do not invent injuries, fixtures, or stats. "
        "When recommending transfers or captaincy, explain the reasoning clearly, "
        "including form, minutes, fixture quality, and risk."
    ),
    tools=[
        function_tool(get_bootstrap_data),
        function_tool(get_fixtures),
        function_tool(get_live_gameweek_data),
        function_tool(get_player_detail),
        function_tool(get_manager_team),
        function_tool(rank_captain_candidates),
    ],
)

# %% [markdown]
# ## Adding an agent that returns the manager's team

# %%
fpl_team_agent = Agent(
    name="FPL Team Viewer",
    instructions=(
        "You only retrieve a manager's FPL team for a specific gameweek. "
        "Use the `get_manager_team` tool when the user provides a team ID and gameweek. "
        "Do not answer captaincy, transfer, fixture, or general analysis questions. "
        "If either the team ID or gameweek is missing, ask for the missing value."
    ),
    tools=[function_tool(get_manager_team)],
)

# %%
TEAM_PROMPT_TEMPLATE = (
    "Use get_manager_team with team_id={team_id} and gameweek={gameweek}. "
    "Return only the manager team data."
)

team_id = 15638
gameweek = 31

result = await Runner.run(
    fpl_team_agent,
    TEAM_PROMPT_TEMPLATE.format(team_id=team_id, gameweek=gameweek),
)

print(result.final_output)
# Out:
# {
#   "entry": {
#     "id": 15638,
#     "name": "FPL MasterChef",
#     "player_first_name": "Tshepo",
#     "player_last_name": "Vilakazi",
#     "player_region_name": "South Africa",
#     "summary_overall_points": 1739,
#     "summary_overall_rank": 1143693,
#     "summary_event_points": 56,
#     "summary_event_rank": 2196409,
#     "current_event": 31,
#     "leagues": {...}
#   },
#   "picks": {
#     "active_chip": null,
#     "automatic_subs": [],
#     "entry_history": {
#       "event": 31,
#       "points": 56,
#       "total_points": 1739,
#       "rank": 2196409,
#       "overall_rank": 1143693,
#       "percentile_rank": 20,
#       "bank": 5,
#       "value": 1020,
#       "event_transfers": 0,
#       "event_transfers_cost": 0,
#       "points_on_bench": 0
#     },
#     "picks": [
#       {"element": 470, "position": 1, "multiplier": 1, "element_type": 1},
#       {"element": 683, "position": 2, "multiplier": 1, "element_type": 2},
#       {"element": 260, "position": 3, "multiplier": 1, "element_type": 2},
#       {"element": 348, "position": 4, "multiplier": 1, "element_type": 2},
#       {"element": 119, "position": 5, "multiplier": 1, "element_type": 3},
#       {"element": 449, "position": 6, "multiplier": 2, "element_type": 3},
#       {"element": 329, "position": 7, "multiplier": 1, "element_type": 3},
#       {"element": 807, "position": 8, "multiplier": 1, "element_type": 3},
#       {"element": 660, "position": 9, "multiplier": 1, "element_type": 3},
#       {"element": 661, "position": 10, "multiplier": 1, "element_type": 4},
#       {"element": 136, "position": 11, "multiplier": 1, "element_type": 4},
#       {"element": 1, "position": 12, "multiplier": 0, "element_type": 1},
#       {"element": 430, "position": 13, "multiplier": 0, "element_type": 4},
#       {"element": 5, "position": 14, "multiplier": 0, "element_type": 2},
#       {"element": 411, "position": 15, "multiplier": 0, "element_type": 2}
#     ]
#   }
# }

# %% [markdown]
# ## Experimenting with structured Output

# %%
TEAM_PROMPT_TEMPLATE = (
    "Use get_manager_team with team_id={team_id} and gameweek={gameweek}. "
    "Return only the manager team data in the required schema."
)

team_id = 5196911
gameweek = 30

result = await Runner.run(
    fpl_team_agent,
    TEAM_PROMPT_TEMPLATE.format(team_id=team_id, gameweek=gameweek),
)

team_doc: TeamDoc = result.final_output
print(team_doc)
# Out:
# team_id=5196911 gameweek=30 manager_name='Tumelo Konaite' team_name='Captain Levi' entry=EntryInfo(id=5196911, player_first_name='Tumelo', player_last_name='Konaite', player_region_name='South Africa', name='Captain Levi', summary_overall_points=1697, summary_event_points=60, summary_overall_rank=1955689, last_deadline_bank=62, last_deadline_value=1021, last_deadline_total_transfers=30) active_chip=None picks=[PickItem(element=470, position=1, multiplier=1, is_captain=False, is_vice_captain=False, element_type=1), PickItem(element=8, position=2, multiplier=1, is_captain=False, is_vice_captain=False, element_type=2), PickItem(element=260, position=3, multiplier=1, is_captain=False, is_vice_captain=False, element_type=2), PickItem(element=373, position=4, multiplier=1, is_captain=False, is_vice_captain=False, element_type=2), PickItem(element=74, position=5, multiplier=1, is_captain=False, is_vice_captain=False, element_type=2), PickItem(element=21, position=6, multiplier=1, is_captain=False, is_vice_captain=False, element_type=3), PickItem(element=449, position=7, multiplier=2, is_captain=True, is_vice_captain=False, element_type=3), PickItem(element=82, position=8, multiplier=1, is_captain=False, is_vice_captain=False, element_type=3), PickItem(element=249, position=9, multiplier=1, is_captain=False, is_vice_captain=False, element_type=4), PickItem(element=136, position=10, multiplier=1, is_captain=False, is_vice_captain=True, element_type=4), PickItem(element=661, position=11, multiplier=1, is_captain=False, is_vice_captain=False, element_type=4), PickItem(element=220, position=12, multiplier=0, is_captain=False, is_vice_captain=False, element_type=1), PickItem(element=329, position=13, multiplier=0, is_captain=False, is_vice_captain=False, element_type=3), PickItem(element=47, position=14, multiplier=0, is_captain=False, is_vice_captain=False, element_type=3), PickItem(element=374, position=15, multiplier=0, is_captain=False, is_vice_captain=False, element_type=2)] automatic_subs=[]

# %%
# Saving it as JSON
def save_team_as_json(team_doc: TeamDoc, output_path: str = "team_doc.json") -> None:
    Path(output_path).write_text(
        team_doc.model_dump_json(indent=2),
        encoding="utf-8",
    )

# %%
save_team_as_json(team_doc, "fpl_team_gw30.json")
